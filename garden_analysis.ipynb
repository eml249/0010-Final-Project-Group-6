# %% [markdown]
# Introduction
# This analysis aims to explore the distribution of community gardens in Pittsburgh neighborhoods, with a particular focus on Bloomfield (zip code 15224). The purpose is to understand where community gardens are located across the city, identify which neighborhoods have the highest number or density of gardens, and discuss factors like accessibility and neighborhood engagement in urban gardening initiatives. The Bloomfield neighborhood was chosen due to its unique position within the city, serving as an example of a mid-sized urban area with growing interest in community-driven green spaces. Alternatively, this analysis will also examine multiple neighborhoods to offer a comparative view of community garden distribution across the city.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Dictionary mapping each zip code to its respective neighborhood(s)
zip_to_neighborhood = {
    15201: "City of Pittsburgh (Lawrenceville & Stanton Heights)",
    15202: "Not City – Boroughs of Bellevue, Avalon, Ben Avon, Emsworth and Townships of Kilbuck, Ohio & Ross",
    15203: "City of Pittsburgh (Southside)",
    15204: "Part City (Sheraden, Elliott, Esplen & Broadhead)",
    15205: "Part Ingram Borough",
    15206: "City of Pittsburgh (East Liberty, Morningside & East End)",
    15207: "City of Pittsburgh (Hazelwood, Greenfield, Glenwood, Glen Hazel, Hays & Lincoln Pl)",
    15208: "City of Pittsburgh (Homewood, Brushton, East End & Point Breeze)",
    15209: "Not City – Millvale Borough & Townships of Shaler, Reserve & Ross",
    15210: "Part City (Knoxville, Beltzhoover, Carrick & Arlington)",
    15211: "City of Pittsburgh (Mt Washington & Duquesne Heights)",
    15212: "Part City (Northside)",
    15213: "City of Pittsburgh (Oakland & Bellefield)",
    15214: "Part City (Northside)",
    15215: "Part City – Sharpsburg, Aspinwall & Fox Chapel, Townships of O’Hara, Indiana & Shaler",
    15216: "Part City (Beechview)",
    15217: "City of Pittsburgh (Squirrel Hill, Greenfield & Browns Hill)",
    15218: "Part City (Regent Square & Swisshelm Park)",
    15219: "City of Pittsburgh (Uptown, Herron Hill & Schenley Heights)",
    15220: "Part City (West End, Wabash, Westwood & Banksville)",
    15221: "Part City (Brushton, Homewood & East Hills)",
    15222: "City of Pittsburgh (Downtown)",
    15223: "Not City – Borough of Etna and Township of Shaler",
    15224: "City of Pittsburgh (Bloomfield & Garfield)",
    15225: "Not City – Township of Neville & Neville Island",
    15226: "Part City (Brookline & Overbrook)",
    15227: "Part City (Carrick & Overbrook)",
    # Continue this mapping for other zip codes as needed
}

# Load the dataset
data = pd.read_csv("community_gardens2017.csv")

# Map zip codes to neighborhoods and create a new column
data['neighborhood'] = data['zip_code'].map(zip_to_neighborhood)

# %% [markdown]
# Filter by Zip Code
# Filtering for data specific to the Bloomfield neighborhood:

# %%
# Filter by Bloomfield neighborhood using zip code 15224
bloomfield_gardens = data[data['zip_code'] == 15224]

# Or filter by the neighborhood description
bloomfield_gardens_by_name = data[data['neighborhood'] == "City of Pittsburgh (Bloomfield & Garfield)"]

# Display the filtered data
bloomfield_gardens.head()
# Out:
#     _id                  urban_grower  grower_id               category  \
# 18   19       Garfield Community Farm        671         community-farm
# 53   54  Waldorf School of Pittsburgh        707          school-garden
# 57   58       Garfield Community Farm        711  commercial-urban-farm
#
#                                                   url  \
# 18  https://www.growpittsburgh.org/directory/garde...
# 53  https://www.growpittsburgh.org/directory/garde...
# 57  https://www.growpittsburgh.org/directory/garde...
#
#                   street_address        city         state  zip_code country  \
# 18                 527 Edlam Way  Pittsburgh  Pennsylvania   15224.0      US
# 53       201 S Winebiddle Street  Pittsburgh  Pennsylvania   15224.0      US
# 57  Cornwall St & Wicklow Street  Pittsburgh  Pennsylvania   15224.0      US
#
#      latitude  longitude                                neighborhood
# 18  40.469378 -79.935125  City of Pittsburgh (Bloomfield & Garfield)
# ...

# %% [markdown]
# The Metric
# For this analysis, the chosen metric is the number of community gardens per neighborhood, as it provides a direct count of urban gardening initiatives and is straightforward to visualize and analyze. This approach will give a clear picture of how many gardens are concentrated in each zip code. Bloomfield will be compared against other neighborhoods in Pittsburgh to understand how it ranks within the broader city context.
#
# To calculate this metric:
#
# Count the number of community gardens per zip code: This involves aggregating the number of gardens within each neighborhood (based on zip code) from the dataset.
# Visualize the data: Using bar charts or other visualizations to highlight differences in the number of community gardens across Pittsburgh neighborhoods. This will help identify areas with a higher concentration of community gardens.
#
# Best Neighborhood Analysis
# To find the "best" neighborhood in terms of community gardens, Bloomfield will be compared to other neighborhoods using the following steps:
#
# Counting the community gardens: The number of gardens per zip code will be counted and recorded for all neighborhoods in Pittsburgh.
# Data visualization: A bar plot or similar chart will be used to visualize the distribution of gardens across neighborhoods. This will allow for easy comparison and identification of neighborhoods with the highest garden counts.
# Comparative analysis: By visualizing these counts, differences between Bloomfield and other neighborhoods will be highlighted. This will show where Bloomfield stands relative to other neighborhoods in terms of community garden abundance.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Dictionary mapping each zip code to its respective neighborhood(s)
zip_to_neighborhood = {
    15201: "City of Pittsburgh (Lawrenceville & Stanton Heights)",
    15202: "Not City – Boroughs of Bellevue, Avalon, Ben Avon, Emsworth and Townships of Kilbuck, Ohio & Ross",
    15203: "City of Pittsburgh (Southside)",
    15204: "Part City (Sheraden, Elliott, Esplen & Broadhead)",
    15205: "Part Ingram Borough",
    15206: "City of Pittsburgh (East Liberty, Morningside & East End)",
    15207: "City of Pittsburgh (Hazelwood, Greenfield, Glenwood, Glen Hazel, Hays & Lincoln Pl)",
    15208: "City of Pittsburgh (Homewood, Brushton, East End & Point Breeze)",
    15209: "Not City – Millvale Borough & Townships of Shaler, Reserve & Ross",
    15210: "Part City (Knoxville, Beltzhoover, Carrick & Arlington)",
    15211: "City of Pittsburgh (Mt Washington & Duquesne Heights)",
    15212: "Part City (Northside)",
    15213: "City of Pittsburgh (Oakland & Bellefield)",
    15214: "Part City (Northside)",
    15215: "Part City – Sharpsburg, Aspinwall & Fox Chapel, Townships of O’Hara, Indiana & Shaler",
    15216: "Part City (Beechview)",
    15217: "City of Pittsburgh (Squirrel Hill, Greenfield & Browns Hill)",
    15218: "Part City (Regent Square & Swisshelm Park)",
    15219: "City of Pittsburgh (Uptown, Herron Hill & Schenley Heights)",
    15220: "Part City (West End, Wabash, Westwood & Banksville)",
    15221: "Part City (Brushton, Homewood & East Hills)",
    15222: "City of Pittsburgh (Downtown)",
    15223: "Not City – Borough of Etna and Township of Shaler",
    15224: "City of Pittsburgh (Bloomfield & Garfield)",
    15225: "Not City – Township of Neville & Neville Island",
    15226: "Part City (Brookline & Overbrook)",
    15227: "Part City (Carrick & Overbrook)",
    # Continue this mapping for other zip codes as needed
}

# Load the dataset
data = pd.read_csv("community_gardens2017.csv")

# Map zip codes to neighborhoods and create a new column
data['neighborhood'] = data['zip_code'].map(zip_to_neighborhood)




# Group by zip code and count community gardens per neighborhood
neighborhood_counts = data.groupby('zip_code').size().reset_index(name='garden_count')

# Define a dictionary mapping zip codes to neighborhood names
zip_to_neighborhood = {
    15201: "Lawrenceville & Stanton Heights",
    15202: "Boroughs of Bellevue, Avalon, Ben Avon, Emsworth and Townships of Kilbuck, Ohio & Ross",
    15203: "Southside",
    15204: "Sheraden, Elliott, Esplen & Broadhead",
    15205: "Ingram Borough",
    15206: "East Liberty, Morningside & East End",
    15207: "Hazelwood, Greenfield, Glenwood, Glen Hazel, Hays & Lincoln Pl",
    15208: "City of Pittsburgh (Homewood, Brushton, East End & Point Breeze)",
    15209: "Millvale Borough & Townships of Shaler, Reserve & Ross",
    15210: "Knoxville, Beltzhoover, Carrick & Arlington",
    15211: "Mt Washington & Duquesne Heights",
    15212: "Northside",
    15213: "Oakland & Bellefield",
    15214: "Northside",
    15215: "Sharpsburg, Aspinwall & Fox Chapel, Townships of O’Hara, Indiana & Shaler",
    15216: "Beechview",
    15217: "Squirrel Hill, Greenfield & Browns Hill",
    15218: "Regent Square & Swisshelm Park",
    15219: "Uptown, Herron Hill & Schenley Heights",
    15220: "West End, Wabash, Westwood & Banksville",
    15221: "Brushton, Homewood & East Hills",
    15222: "Downtown",
    15223: "Borough of Etna and Township of Shaler",
    15224: "Bloomfield & Garfield",
    15225: "Township of Neville & Neville Island",
    15226: "Brookline & Overbrook",
    15227: "Carrick & Overbrook",
}

# Define colors for each neighborhood, using a color palette
unique_neighborhoods = neighborhood_counts['zip_code'].map(zip_to_neighborhood).fillna('Other').unique()
color_palette = sns.color_palette("husl", len(unique_neighborhoods))
neighborhood_colors = {neighborhood: color for neighborhood, color in zip(unique_neighborhoods, color_palette)}

# Assign colors to each bar, using a default color for unmapped zip codes
colors = [neighborhood_colors.get(zip_to_neighborhood.get(zip_code, 'Other'), neighborhood_colors['Other']) for zip_code in neighborhood_counts['zip_code']]

# Visualize community gardens by neighborhood with customized colors and rotated labels
plt.figure(figsize=(14, 8))
bars = sns.barplot(data=neighborhood_counts, x='zip_code', y='garden_count', palette=colors)

# Add labels and rotate them for better readability
plt.title("Community Gardens by Neighborhood (Zip Code)", fontsize=16)
plt.xlabel("Zip Code", fontsize=14)
plt.ylabel("Number of Community Gardens", fontsize=14)
plt.xticks(rotation=90, fontsize=10)

# Create a custom legend
from matplotlib.patches import Patch
legend_patches = [Patch(color=color, label=neighborhood) for neighborhood, color in neighborhood_colors.items()]
plt.legend(handles=legend_patches, title="Neighborhood", loc='upper right', bbox_to_anchor=(1.25, 1))

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/sr/tvnl1z9s1s3gkkv9m10fnmjr0000gn/T/ipykernel_8701/775382490.py:91: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(data=neighborhood_counts, x='zip_code', y='garden_count', palette=colors)

# %% [markdown]
# Conclusion
# In this analysis, we focused on the distribution of community gardens across Pittsburgh neighborhoods, with a particular emphasis on Bloomfield (zip code 15224) and its surrounding areas, including Garfield. According to the data, Bloomfield/Garfield has three community gardens, which is a moderate count compared to other neighborhoods. However, the neighborhood with the highest number of community gardens is zip code 15206, which encompasses East Liberty, Morningside, and parts of the East End. This area stands out with a significantly higher number of community gardens, indicating a more concentrated interest or resources for urban gardening in that part of Pittsburgh.
#
# Despite Bloomfield/Garfield’s three gardens, which contribute to a notable presence of community-driven green spaces, 15206’s higher number of gardens may suggest that East Liberty and its surrounding areas are more actively involved in or supported by community gardening initiatives. This could be due to factors such as greater community engagement, availability of public space, or active local organizations promoting green spaces.
#
# This data provides a clear, data-driven snapshot of Pittsburgh’s community garden landscape, highlighting both the areas with the most extensive gardening networks (like 15206) and neighborhoods with fewer resources (like Bloomfield/Garfield). Understanding these dynamics can help guide future efforts to increase access to urban gardens in neighborhoods like Bloomfield that may benefit from more community-driven green spaces.
#
# individual reflection:
# From my perspective, while the data points to 15206 as the neighborhood/area with the highest number of community gardens, I find that the Bloomfield and Garfield area still offers a unique, community-centered atmosphere for gardening. With only three gardens, these neighborhoods might not have the highest concentration of green spaces, but the existing gardens are highly valued and foster a strong sense of community. For example, the smaller number of gardens in Bloomfield/Garfield might also mean that these spaces are more intimately connected to their local residents, offering personalized, smaller-scale engagement that is less likely to be found in larger garden clusters.
#
# Personally, I value neighborhoods like Bloomfield that have fewer gardens but a more grassroots, neighbor-driven approach to urban gardening. In contrast, East Liberty (15206) with its higher number of gardens may reflect a more institutionalized or larger-scale effort to incorporate gardening into the urban landscape. While this may provide more opportunities for engagement, it might lack the personal, local touch that smaller neighborhoods like Bloomfield/Garfield offer.
#
# In summary, while the data-driven analysis clearly points to 15206 as the "best" neighborhood in terms of garden quantity, I believe that Bloomfield/Garfield holds its own value. The smaller number of gardens does not necessarily detract from the sense of community and impact these spaces can have on local residents. Additionally, while I appreciate the density of gardens in 15206, I would argue that the heart of community gardening in Pittsburgh lies in neighborhoods like Bloomfield, where smaller but meaningful green spaces can have a profound impact on neighborhood well-being and engagement.
